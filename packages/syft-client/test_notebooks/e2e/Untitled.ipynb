# %%
import sys
sys.path.insert(0, '../..')
import syft_client as sc
import syft_serve as ss

# %%
andrew = sc.login("andrew@openmined.org")
# Out:
# ✅ Connected peer-to-peer to 2 peers via: Gmail, Gdrive_Files, Gsheets, Gforms

# %%
andrew.logs
# Out:
# LogsView(Watcher: port 8000, Receiver: port 8002, Job Runner: port 8003)
