# %%
import sys
sys.path.insert(0, '../..')
import syft_client as sc
import syft_serve as ss

# %%
liam = sc.login("liamtrask@gmail.com")
# Out:
# ✅ Connected peer-to-peer to 2 peers via: Gmail, Gdrive_Files, Gsheets, Gforms

# %%
liam.logs
# Out:
# LogsView(Watcher: port 8001, Receiver: port 8004, Job Runner: port 8005)
