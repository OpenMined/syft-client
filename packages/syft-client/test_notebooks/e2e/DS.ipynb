# %%
import sys
sys.path.insert(0, '../..')
import syft_client as sc
import syft_serve as ss
from pathlib import Path

# %%
ss.terminate_all()
# Out:
# 0

# %%
# ds_email = input("Enter DS email: ")
ds_email = "liamtrask@gmail.com"
ds_client = sc.login(ds_email)
# Out:
# ✅ Connected peer-to-peer to 2 peers via: Gmail, Gdrive_Files, Gsheets, Gforms

# %% [markdown]
# ## Propose Analysis

# %%
code_path = Path(".") / "code"
code_path.mkdir(exist_ok=True)

code_file_name = "main.py"
code_file_path = code_path / code_file_name

# %%
# %%writefile {code_file_path}
#
# import syft_client as sc
#
# data_path = "syft://private/crop_data/data.csv"
# resolved_path = sc.resolve_path(data_path)
# import csv
#
# with open(resolved_path, 'r') as file:
#     csv_reader = csv.DictReader(file)
#     total_quantity = 0
#     for row in csv_reader:
#         quantity = int(row['Quantity'])
#         total_quantity += quantity
#
#     print(f"Total Quantity: {total_quantity}")
# Out:
# Overwriting code/main.py

# %% [markdown]
# ### Submit Python Job

# %%
# do_email = input("Enter DO email: ")
do_email = "andrew@openmined.org"

do_client = sc.login("andrew@openmined.org")
# Out:
# ✅ Connected peer-to-peer to 2 peers via: Gmail, Gdrive_Files, Gsheets, Gforms

# %%
ds_client.logs
# Out:
# LogsView(Watcher: port 8000, Receiver: port 8001, Job Runner: port 8002)

# %%
do_client.logs
# Out:
# LogsView(Watcher: port 8003, Receiver: port 8004, Job Runner: port 8005)

# %%
import time

for _i in range(10):
    i = _i + 1000
    job = ds_client.submit_python_job(
        user=do_email,
        code_path=code_file_path,
        job_name="job_" + str(i) + "_A"
    )
    # no pause between them
    job = ds_client.submit_python_job(
        user=do_email,
        code_path=code_file_path,
        job_name="job_" + str(i) + "_B"
    )
    # no pause between them
    job = ds_client.submit_python_job(
        user=do_email,
        code_path=code_file_path,
        job_name="job_" + str(i) + "_C"
    )
    # # no pause between them
    # job = ds_client.submit_python_job(
    #     user=do_email,
    #     code_path=code_file_path,
    #     job_name="job_D_" + str(i)
    # )
    sender_len = len(ds_client.jobs)
    time.sleep(40)
    recipient_len = len(do_client.jobs)
    
    if sender_len != recipient_len:
        raise Exception("Something went wrong with job " + str(i))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 33
#      30 recipient_len = len(do_client.jobs)
#      32 if sender_len != recipient_len:
# ---> 33     raise Exception("Something went wrong with job " + str(i))
#
# Exception: Something went wrong with job 1000

# %%
# print(ss.servers[4].stdout.tail(50))

# %% [markdown]
# ## Job Status

# %%
# TODO: Replace this with Peer Client once Ready
import syft_job as sj

do_client = sj.get_client(ds_client.folder, do_email)

# %%
do_client.jobs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 do_client.jobs
#
# NameError: name 'do_client' is not defined

# %%
do_client.jobs[0]
# Out:
# JobInfo(name='Job - 497d3df1', user='andrew@openmined.org', status='done')

# %%
do_client.jobs[0].stdout
# Out:
# Total Quantity: 2631
