# %%
from syft_job.job_runner import create_runner

# %%
syftbox_folder_path = input("Enter the Syftbox folder path: ")
email = input("Enter syftbox email: ")
runner = create_runner(str(syftbox_folder_path), email)

# %%
runner.run()
