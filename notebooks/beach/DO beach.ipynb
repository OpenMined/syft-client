# %%
# !uv pip install -qU syft-client

# %%
import syft_client as sc

# %%
from syft_client.version import SYFT_CLIENT_VERSION
SYFT_CLIENT_VERSION

# %%
credentials_path = "../credentials/client_secret_6089090818-sdp874bcihdcr0hau0l48vc5e7621fhl.apps.googleusercontent.com.json"

# %%
# token_path = "../credentials/token.json"
token_path = sc.credentials_to_token(credentials_path)

# %%
# do_client = login_do(email="your@email.com", token_path=token_path) # for second time login
client = sc.login_do(email="do@openmined.org", token_path=token_path)

# %%
client.add_peer("ds@openmined.org")

# %%
client.peers

# %%
client.create_dataset(
    name="testdata",
    mock_path="mock.txt",
    private_path="private.txt",
    users=["ds@openmined.org"],
)

# %%
client.sync()

# %%
# client.peer_manager.ignore_client_version=True

# %%
client.jobs

# %%
client.jobs[0].approve()

# %%
client.process_approved_jobs(share_outputs_with_submitter=True)

# %%
client.sync()

# %%
client.jobs[0].output_paths

# %%
client.sync()
