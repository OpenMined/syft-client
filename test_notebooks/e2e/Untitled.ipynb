# %%
import sys
sys.path.insert(0, '../..')
import syft_client as sc

# %%
client = sc.login()
# Out:
# 📧 Multiple email accounts found in ~/.syft:
#   1. liamtrask@gmail.com
#   2. andrew@openmined.org
#   3. Enter a different email
# Select an option (1-3):  2
# ✅ Connected peer-to-peer to 2 peers via: Gmail, Gdrive_Files, Gsheets, Gforms

# %%
client
# Out:
# ╭────── SyftClient.email = 'andrew@openmined.org' ───────╮
# │                                                        │
# │  .folder = /Users/atrask/SyftBox_andrew@openmined.org  │
# │                                                        │
# │  .platforms (for peer-to-peer communication)           │
# │    .google_org (2 peers)                               │
# │      ✓ ✓ .gmail (2 peers)                              │
# │      ✓ ✓ .gdrive_files (2 peers)                       │
# │      ✓ ✓ .gsheets (2 peers)                            │
# │      ✓ ✓ .gforms                                       │
# │                                                        │
# │  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━    │
# │                                                        │
# │  .peers  (2 active, 0 pending)                         │
# │                                                        │
# │    [0] atrask@google.com                               │
# ...

# %%
client.logs
# Out:
# LogsView(Watcher: port 8000, Receiver: port 8001, Job Runner: port 8002)
